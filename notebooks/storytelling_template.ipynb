# %% [markdown]
# # Storytelling Notebook
#
# Notebook này nhận **đường dẫn file CSV** từ biến `input_path`, sau đó đọc dữ liệu và hiển thị `df.head()`.
#
# Khi chạy bằng papermill, bạn chỉ cần truyền tham số `input_path` từ bên ngoài.

# %%
# Parameters
# Biến này sẽ được papermill override từ bên ngoài.
# Giá trị default để bạn có thể chạy thử tay trong Jupyter.
input_path = "data.csv"  # thay bằng đường dẫn mặc định nếu muốn

# %%
import pandas as pd

print(f"Đọc file CSV từ: {input_path}")
df = pd.read_csv(input_path)
df.head()
